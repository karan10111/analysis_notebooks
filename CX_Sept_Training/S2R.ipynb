# %%
import os
import base64
from sqlalchemy import create_engine
import pymysql
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sys

# %%
ipaddr = 'speak2recharge.mysql.database.azure.com'
db_name = 'speech_process'
passwd = 'S2RPass7'
userid = 'myadmin@speak2recharge'
dest_sql = "mysql+mysqldb://" + userid + ":" + passwd + "@" + ipaddr + "/" + db_name + "?charset=utf8&use_unicode=0"
sql_engine = create_engine(dest_sql,pool_recycle=3600)
db_connection    = sql_engine.connect()

# %%
tables = pd.read_sql("show tables;", db_connection)
tables
# Out:
#                  Tables_in_speech_process
# 0    b'acoustic_training_tables_metadata'
# 1                     b'data16_0105_1705'
# 2                     b'data16_0105_3105'
# 3                     b'data16_0106_1506'
# 4                     b'data16_0107_0108'
# ..                                    ...
# 452                               b'test'
# 453                    b'test_lang_check'
# 454              b'test_language_kannada'
# 455              b'test_language_marathi'
# 456              b'wipro_transcribe_2709'
#
# [457 rows x 1 columns]

# %%
tags = pd.read_sql("select distinct(tag) from s2r_hindi_vs_3_lifestyle_1_27082020;", db_connection)
tags
# Out:
#    tag
# 0   51
# 1   52

# %% [markdown]
# #### Comment: Make sure that domain tags 39, 37 are devnagri only.

# %%
tags = pd.read_sql("select distinct(tag) from data_hindi_tag_39_010419;", db_connection)
tags
# Out:
#    tag
# 0   39

# %%
check_for_devnagari = pd.read_sql("select * from data_hindi_tag_39_010419 where tag in(37,39);", db_connection)
# improved.Machine_Transcribed_text_x.str.split().apply(len), color='red', label='baseline_predicted_word_len'
check_for_devnagari['utf_text_decoded'] = check_for_devnagari['utf_text'].apply(base64.urlsafe_b64decode).str.decode('utf8')
check_for_devnagari.head()
# Out:
#          id  user_id  text                                           utf_text  \
# 0  20813884   200757  b'0'                            b'4KSV4KWL4KSw4KSyCg=='
# 1  20813885   200757  b'0'  b'4KSo4KWH4KS44KWN4KSy4KWHIOCkuOClh-CksOClh-Ck...
# 2  20813886   200757  b'0'  b'4KSo4KS_4KS14KS_4KSv4KS-IOCkruClh-CkqCDgpKHg...
# 3  20813887   200757  b'0'  b'4KSF4KSu4KWC4KSy4KS44KWN4KSq4KWN4KSw4KWHIOCk...
# 4  20813888   200757  b'0'  b'4KS44KSo4KSr4KWA4KS44KWN4KSfIOCkuOCli-CksCDg...
#
#                                             base_dir  \
# 0  b'/home/software/data/uploads_v2/hindi/2018-12...
# 1  b'/home/software/data/uploads_v2/hindi/2018-12...
# 2  b'/home/software/data/uploads_v2/hindi/2018-12...
# 3  b'/home/software/data/uploads_v2/hindi/2018-12...
# 4  b'/home/software/data/uploads_v2/hindi/2018-12...
#
#                   audio_file  assigned  tag  flag_decode  hash  \
# 0  b'200757_1_20813884.opus'         1   39            0     9
# ...

# %%
check_for_devnagari = pd.read_sql("select * from data_hindi_tags_2_8_22_36_37_020419 where tag in(37,39);", db_connection)
# improved.Machine_Transcribed_text_x.str.split().apply(len), color='red', label='baseline_predicted_word_len'
check_for_devnagari['utf_text_decoded'] = check_for_devnagari['utf_text'].apply(base64.urlsafe_b64decode).str.decode('utf8')
check_for_devnagari.head()
# Out:
#          id  user_id  text                                           utf_text  \
# 0  17720717    39056  b'0'  b'4KSP4KSu4KWH4KSc4KWJ4KSoIOCkquCljeCksuClhyDg...
# 1  17720719    39056  b'0'  b'4KSV4KSC4KSq4KWN4KSv4KWC4KSf4KSwIOCkquCljeCk...
# 2  17720721    39056  b'0'  b'4KSf4KWI4KSC4KSX4KWLIOCkuOClh-CknyDgpKYg4KSf...
# 3  17720723    39056  b'0'  b'4KSP4KSq4KWN4KSq4KSyIOCkquCljeCksuClhyDgpK7g...
# 4  17720724    39056  b'0'                    b'4KSr4KS-4KSH4KS1IOCkoeClhwo='
#
#                                             base_dir  \
# 0  b'/home/software/data/uploads_v2/hindi/2018-05...
# 1  b'/home/software/data/uploads_v2/hindi/2018-05...
# 2  b'/home/software/data/uploads_v2/hindi/2018-05...
# 3  b'/home/software/data/uploads_v2/hindi/2018-05...
# 4  b'/home/software/data/uploads_v2/hindi/2018-05...
#
#                  audio_file  assigned  tag  flag_decode  hash  \
# 0  b'39056_1_17720717.opus'         1   37            0     9
# ...

# %%
tags = pd.read_sql("select distinct(tag) from data_hindi_tags_2_8_22_36_37_020419;", db_connection)
tags
# Out:
#    tag
# 0   37

# %% [markdown]
# ### Getting Verified Tags

# %%
tags = pd.read_sql("select distinct(verified) from s2r_hindi_vs_3_lifestyle_1_27082020;", db_connection)
tags
# Out:
#    verified
# 0        20

# %%
tags = pd.read_sql("select distinct(verified) from data_hindi_tag_39_010419;", db_connection)
tags
# Out:
#    verified
# 0        20

# %%
tags = pd.read_sql("select distinct(verified) from data_hindi_tags_2_8_22_36_37_020419;", db_connection)
tags
# Out:
#    verified
# 0        20

# %%
observe_columns = pd.read_sql("select * from data_hindi_tags_2_8_22_36_37_020419;", db_connection)
observe_columns.columns
# Out:
# Index(['id', 'user_id', 'text', 'utf_text', 'base_dir', 'audio_file',
#        'assigned', 'tag', 'flag_decode', 'hash', 'upload_date',
#        'verified_time', 'upload_time', 'uploaded', 'verified', 'synced',
#        'last_modifed', 'create_date', 'length'],
#       dtype='object')

# %%
observe_columns.head()
# Out:
#          id  user_id  text                                           utf_text  \
# 0  17720717    39056  b'0'  b'4KSP4KSu4KWH4KSc4KWJ4KSoIOCkquCljeCksuClhyDg...
# 1  17720719    39056  b'0'  b'4KSV4KSC4KSq4KWN4KSv4KWC4KSf4KSwIOCkquCljeCk...
# 2  17720721    39056  b'0'  b'4KSf4KWI4KSC4KSX4KWLIOCkuOClh-CknyDgpKYg4KSf...
# 3  17720723    39056  b'0'  b'4KSP4KSq4KWN4KSq4KSyIOCkquCljeCksuClhyDgpK7g...
# 4  17720724    39056  b'0'                    b'4KSr4KS-4KSH4KS1IOCkoeClhwo='
#
#                                             base_dir  \
# 0  b'/home/software/data/uploads_v2/hindi/2018-05...
# 1  b'/home/software/data/uploads_v2/hindi/2018-05...
# 2  b'/home/software/data/uploads_v2/hindi/2018-05...
# 3  b'/home/software/data/uploads_v2/hindi/2018-05...
# 4  b'/home/software/data/uploads_v2/hindi/2018-05...
#
#                  audio_file  assigned  tag  flag_decode  hash  \
# 0  b'39056_1_17720717.opus'         1   37            0     9
# ...
