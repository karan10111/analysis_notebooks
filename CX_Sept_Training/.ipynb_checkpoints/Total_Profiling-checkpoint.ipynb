# %%
import os
import base64
from sqlalchemy import create_engine
import pymysql
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sys
sys.path.append("/home/karan.verma")
from verification_guardrails import get_type_of_text

# %%
data_from_s2r = pd.read_csv('/home/sanyam.sood/jupyter_lab_files/s2r_usable.csv')
data_from_s2r.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1        id  user_id  text  \
# 0           0             0  17720717    39056  b'0'
# 1           1             1  17720719    39056  b'0'
# 2           2             2  17720721    39056  b'0'
# 3           3             3  17720723    39056  b'0'
# 4           4             4  17720724    39056  b'0'
#
#                                             utf_text  \
# 0  b'4KSP4KSu4KWH4KSc4KWJ4KSoIOCkquCljeCksuClhyDg...
# 1  b'4KSV4KSC4KSq4KWN4KSv4KWC4KSf4KSwIOCkquCljeCk...
# 2  b'4KSf4KWI4KSC4KSX4KWLIOCkuOClh-CknyDgpKYg4KSf...
# 3  b'4KSP4KSq4KWN4KSq4KSyIOCkquCljeCksuClhyDgpK7g...
# 4                    b'4KSr4KS-4KSH4KS1IOCkoeClhwo='
#
#                                             base_dir  \
# 0  b'/home/software/data/uploads_v2/hindi/2018-05...
# 1  b'/home/software/data/uploads_v2/hindi/2018-05...
# 2  b'/home/software/data/uploads_v2/hindi/2018-05...
# 3  b'/home/software/data/uploads_v2/hindi/2018-05...
# 4  b'/home/software/data/uploads_v2/hindi/2018-05...
#
#                  audio_file  assigned  tag  ...  verified_time  upload_time  \
# 0  b'39056_1_17720717.opus'         1   37  ...            NaN            0
# 1  b'39056_1_17720719.opus'         1   37  ...            NaN            0
# 2  b'39056_1_17720721.opus'         1   37  ...            NaN            0
# 3  b'39056_1_17720723.opus'         1   37  ...            NaN            0
# 4  b'39056_1_17720724.opus'         1   37  ...            NaN            0
#
#   uploaded  verified  synced  last_modifed          create_date  length  \
# 0        1        20       1           NaN  2018-05-17 21:47:23       0
# 1        1        20       1           NaN  2018-05-17 21:47:23       0
# 2        1        20       1           NaN  2018-05-17 21:47:23       0
# 3        1        20       1           NaN  2018-05-17 21:47:23       0
# 4        1        20       1           NaN  2018-05-17 21:47:23       0
#
#                                     utf_text_decoded word_len
# 0  एमेजॉन प्ले माय मोस्ट लिसन टू सोंग्स ऑन गूगल प...       11
# 1          कंप्यूटर प्ले द न्यू एल्बम बाई निर्वाना\n        7
# 2            टैंगो सेट द टाइमर फॉर थर्टी वन मिनट्स\n        8
# 3  एप्पल प्ले माई बुक सीरियस मेन बाई आमिष त्रिपाठी\n        9
# 4                                          फाइव डे\n        2
#
# [5 rows x 23 columns]

# %%
data_from_transcribe = pd.read_csv('/home/sanyam.sood/jupyter_lab_files/transcribe_usable.csv')
data_from_transcribe.head()
# Out:
#    Unnamed: 0   text_id  uploaded  verified  user_id  tag  verified_by  \
# 0           0  41966759         1         1     6710  275          154
# 1           1  41966760         1        11     6710  275          154
# 2           2  41966761         1         1     6709  275          154
# 3           3  41966762         1         1     6709  275          154
# 4           4  41966763         1         1     6709  275          154
#
#    length  confidence  uploaded_time  ... seq_id test_data lang lang_lm  \
# 0    2592    0.684045            NaN  ...      0         0    1       0
# 1    1872    0.732568            NaN  ...      0         0    1       0
# 2    1692    0.706878            NaN  ...      0         0    1       0
# 3    2376    0.704331            NaN  ...      0         0    1       0
# 4    2232    0.704821            NaN  ...      0         0    1       0
#
#   auto_lang  current_month_verification srv_session_id  \
# 0     b'NA'                           0            NaN
# 1     b'NA'                           0            NaN
# 2     b'NA'                           0            NaN
# 3     b'NA'                           0            NaN
# 4     b'NA'                           0            NaN
#
#    corrected_utf_text_decoded  type_of_text  word_len
# 0                 शो मी मिल्क             0         3
# 1              शो मी चॉकलेट्स             0         3
# 2                चिप्स दिखाना             0         2
# 3                चिप्स दिखाना             0         2
# 4                चिप्स दिखाना             0         2
#
# [5 rows x 30 columns]

# %%
data_from_cx = pd.read_csv('/home/sanyam.sood/jupyter_lab_files/cx_usable.csv')
data_from_cx.head()
# Out:
#    Unnamed: 0   text_id  uploaded  verified  user_id  tag  verified_by  \
# 0           0  42908288         0         1     6723  277          252
# 1           1  42908294         0         1     6723  277          252
# 2           4  42908305         0         1     6723  277          252
# 3           5  42908306         0         1     6723  277          252
# 4           9  42908335         0         1     6723  277          252
#
#    length  confidence  uploaded_time  ... test_data lang lang_lm auto_lang  \
# 0    3096    0.825225            NaN  ...         0    1       0     b'NA'
# 1    3096    0.620411            NaN  ...         0    1       0     b'NA'
# 2    3096    0.739678            NaN  ...         0    1       0     b'NA'
# 3    5076    0.772560            NaN  ...         0    1       0     b'NA'
# 4    8100    0.659289            NaN  ...         0    1       0     b'NA'
#
#   current_month_verification  srv_session_id  \
# 0                          1             NaN
# 1                          1             NaN
# 2                          1             NaN
# 3                          1             NaN
# 4                          1             NaN
#
#                           corrected_utf_text_decoded  type_of_text  \
# 0                                      आवाज आ रही है             0
# 1                        हाँ वो क्रीम अलग न देता और              0
# 2          हाँ जी और वो डेबिट कार्ड से पैसा भी ले ली             0
# 3  दि मैसेज दैट द अमाउंट हैज़ बीन रीफंडेड एंड ईट व...             0
# 4  तो ये न सिर्फ मेरे,मेरे इससे ही नहीं कर पा रहा...             0
#
#                                           audio_path  word_len
# 0  /shared3/all_transcription_flacs/gluster_share...         4
# 1  /shared3/all_transcription_flacs/gluster_share...         7
# 2  /shared3/all_transcription_flacs/gluster_share...        11
# 3  /shared3/all_transcription_flacs/gluster_share...        17
# 4  /shared3/all_transcription_flacs/gluster_share...        28
#
# [5 rows x 31 columns]

# %% [markdown]
# # S2R Plot 1

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.set_style("darkgrid")

data_from_s2r_less_6 = data_from_s2r[data_from_s2r.word_len<=6]
data_from_s2r_less_6 = data_from_s2r_less_6.sample(frac=0.08, random_state=10)

data_from_s2r_greater_6_less_10 = data_from_s2r[(data_from_s2r.word_len>6) & (data_from_s2r.word_len<=9)]
data_from_s2r_greater_6_less_10 = data_from_s2r_greater_6_less_10.sample(frac=0.45, random_state=14)

data_from_s2r_greater_9 = data_from_s2r[data_from_s2r.word_len>=10]

data_from_s2r_usable = pd.concat([data_from_s2r_less_6 ,data_from_s2r_greater_6_less_10 , data_from_s2r_greater_9])
sns.histplot(data_from_s2r_usable.word_len)
# Out:
# <AxesSubplot:xlabel='word_len', ylabel='Count'>

# %%
data_from_s2r_usable.describe()
# Out:
#          Unnamed: 0  Unnamed: 0.1            id        user_id  assigned  \
# count  6.761940e+05  6.761940e+05  6.761940e+05  676194.000000  676194.0
# mean   8.514727e+05  8.514727e+05  2.301053e+07  205282.088528       1.0
# std    5.709035e+05  5.709035e+05  1.421754e+06   21892.813969       0.0
# min    0.000000e+00  0.000000e+00  1.772072e+07   11618.000000       1.0
# 25%    4.065632e+05  4.065632e+05  2.179013e+07  205537.000000       1.0
# 50%    7.089200e+05  7.089200e+05  2.328238e+07  210898.000000       1.0
# 75%    1.194233e+06  1.194233e+06  2.396554e+07  215253.000000       1.0
# max    2.290118e+06  2.290118e+06  2.557538e+07  228383.000000       1.0
#
#                  tag  flag_decode      hash  verified_time  upload_time  \
# count  676194.000000     676194.0  676194.0            0.0     676194.0
# mean       42.129518          0.0       9.0            NaN          0.0
# std         5.471729          0.0       0.0            NaN          0.0
# min        37.000000          0.0       9.0            NaN          0.0
# 25%        39.000000          0.0       9.0            NaN          0.0
# 50%        39.000000          0.0       9.0            NaN          0.0
# 75%        51.000000          0.0       9.0            NaN          0.0
# max        52.000000          0.0       9.0            NaN          0.0
#
#        uploaded  verified         synced  last_modifed    length  \
# count  676194.0  676194.0  676194.000000           0.0  676194.0
# mean        1.0      20.0       0.995427           NaN       0.0
# std         0.0       0.0       0.067467           NaN       0.0
# min         1.0      20.0       0.000000           NaN       0.0
# 25%         1.0      20.0       1.000000           NaN       0.0
# 50%         1.0      20.0       1.000000           NaN       0.0
# 75%         1.0      20.0       1.000000           NaN       0.0
# max         1.0      20.0       1.000000           NaN       0.0
#
#             word_len
# count  676194.000000
# mean        8.846568
# std         3.255934
# min         1.000000
# 25%         7.000000
# 50%         9.000000
# 75%        11.000000
# max        31.000000

# %% [markdown]
# # S2R Plot 2

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.set_style("darkgrid")

arr = np.arange(3,63,2)

data_from_s2r_less_6 = data_from_s2r[data_from_s2r.word_len<=6]
data_from_s2r_less_6 = data_from_s2r_less_6.sample(frac=0.08, random_state=10)

data_from_s2r_7 = data_from_s2r[(data_from_s2r.word_len==7)]
data_from_s2r_7 = data_from_s2r_7.sample(frac=0.45, random_state=14)

data_from_s2r_8_9 = data_from_s2r[(data_from_s2r.word_len==8) | (data_from_s2r.word_len==9)]
data_from_s2r_8_9 = data_from_s2r_8_9.sample(frac=0.55, random_state=13)

data_from_s2r_greater_9 = data_from_s2r[data_from_s2r.word_len>=10]

data_from_s2r_usable = pd.concat([data_from_s2r_less_6 ,data_from_s2r_7 , data_from_s2r_8_9 ,data_from_s2r_greater_9])
sns.histplot(data_from_s2r_usable.word_len)
# Out:
# <AxesSubplot:xlabel='word_len', ylabel='Count'>

# %%
data_from_s2r_usable.describe()
# Out:
#          Unnamed: 0  Unnamed: 0.1            id        user_id  assigned  \
# count  7.097790e+05  7.097790e+05  7.097790e+05  709779.000000  709779.0
# mean   8.497497e+05  8.497497e+05  2.300642e+07  205264.497782       1.0
# std    5.695930e+05  5.695930e+05  1.422810e+06   21849.149564       0.0
# min    0.000000e+00  0.000000e+00  1.772072e+07   11618.000000       1.0
# 25%    4.052960e+05  4.052960e+05  2.178836e+07  205515.000000       1.0
# 50%    7.081000e+05  7.081000e+05  2.328121e+07  210891.000000       1.0
# 75%    1.189488e+06  1.189488e+06  2.395761e+07  215249.000000       1.0
# max    2.290118e+06  2.290118e+06  2.557538e+07  228383.000000       1.0
#
#                  tag  flag_decode      hash  verified_time  upload_time  \
# count  709779.000000     709779.0  709779.0            0.0     709779.0
# mean       42.118886          0.0       9.0            NaN          0.0
# std         5.464662          0.0       0.0            NaN          0.0
# min        37.000000          0.0       9.0            NaN          0.0
# 25%        39.000000          0.0       9.0            NaN          0.0
# 50%        39.000000          0.0       9.0            NaN          0.0
# 75%        51.000000          0.0       9.0            NaN          0.0
# max        52.000000          0.0       9.0            NaN          0.0
#
#        uploaded  verified         synced  last_modifed    length  \
# count  709779.0  709779.0  709779.000000           0.0  709779.0
# mean        1.0      20.0       0.995401           NaN       0.0
# std         0.0       0.0       0.067657           NaN       0.0
# min         1.0      20.0       0.000000           NaN       0.0
# 25%         1.0      20.0       1.000000           NaN       0.0
# 50%         1.0      20.0       1.000000           NaN       0.0
# 75%         1.0      20.0       1.000000           NaN       0.0
# max         1.0      20.0       1.000000           NaN       0.0
#
#             word_len
# count  709779.000000
# mean        8.826326
# std         3.181217
# min         1.000000
# 25%         7.000000
# 50%         9.000000
# 75%        11.000000
# max        31.000000

# %% [markdown]
# # Transcribe Plot

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.set_style("darkgrid")

data_length_less_6 = data_from_transcribe[data_from_transcribe.word_len<=6]
data_length_less_6 = data_length_less_6.sample(frac=0.09, random_state=10)

data_length_greater_6_less_10 = data_from_transcribe[(data_from_transcribe.word_len>6) & (data_from_transcribe.word_len<10) ]
data_length_greater_6_less_10 = data_length_greater_6_less_10.sample(frac=0.35, random_state=1)

data_length_greater_9 = data_from_transcribe[data_from_transcribe.word_len>9]

data_from_transcribe_usable = pd.concat([data_length_less_6,  data_length_greater_6_less_10, data_length_greater_9])
sns.histplot(data_from_transcribe_usable.word_len)
# Out:
# <AxesSubplot:xlabel='word_len', ylabel='Count'>

# %%
pd.set_option('display.max_rows', None)  

data_from_transcribe_usable.word_len.value_counts()
# Out:
# 10    70048
# 7     50781
# 11    45917
# 8     45831
# 9     35605
# 12    30724
# 2     23732
# 3     22694
# 4     21092
# 13    20319
# 5     19792
# 6     15634
# 14    13267
# 1     12692
# 15     9098
# 16     6117
# 17     4298
# 18     3107
# 19     2227
# 20     1623
# 21     1228
# 22      904
# 23      682
# 24      525
# 25      417
# 26      327
# 27      276
# 28      184
# 29      169
# 30      136
# 31      109
# 32      104
# 33       93
# 35       67
# 34       60
# 36       46
# 37       38
# 38       30
# 39       29
# 42       19
# 40       18
# 41       18
# 45       14
# 43       12
# 44        9
# 46        8
# 48        7
# 49        7
# 51        5
# 52        5
# 50        4
# 60        4
# 47        4
# 54        3
# 58        3
# 65        2
# 53        2
# 55        2
# 57        2
# 59        2
# 71        1
# 56        1
# 62        1
# 0         1
# Name: word_len, dtype: int64

# %%
data_from_transcribe_usable.describe()
# Out:
#          Unnamed: 0       text_id  uploaded       verified        user_id  \
# count  4.601760e+05  4.601760e+05  460176.0  460176.000000  460176.000000
# mean   1.298908e+06  4.531683e+07       1.0       7.952583    6787.369272
# std    6.744389e+05  1.264961e+06       0.0       5.730871      30.613174
# min    3.000000e+00  4.196676e+07       1.0       1.000000    6708.000000
# 25%    7.294190e+05  4.428603e+07       1.0       7.000000    6770.000000
# 50%    1.312534e+06  4.530056e+07       1.0       7.000000    6786.000000
# 75%    1.896447e+06  4.640533e+07       1.0       8.000000    6813.000000
# max    2.407774e+06  4.783642e+07       1.0      18.000000    6839.000000
#
#                  tag    verified_by         length     confidence  \
# count  460176.000000  460176.000000  460176.000000  460176.000000
# mean      283.978845    4290.778085    6446.782692       0.678837
# std         2.350861    1696.335204    2272.741074       0.074853
# min       275.000000       0.000000     936.000000       0.000000
# 25%       284.000000    5008.000000    4716.000000       0.631174
# 50%       285.000000    5038.000000    5976.000000       0.687350
# 75%       285.000000    5065.000000    7452.000000       0.734540
# max       285.000000    5094.000000   15444.000000       0.874107
#
#        uploaded_time  ...  pre_processed       file_id    seq_id  test_data  \
# count            0.0  ...       460176.0  4.601760e+05  460176.0   460176.0
# mean             NaN  ...            0.0  5.000680e+07       0.0        0.0
# std              NaN  ...            0.0  2.884865e+07       0.0        0.0
# min              NaN  ...            0.0  0.000000e+00       0.0        0.0
# 25%              NaN  ...            0.0  2.501626e+07       0.0        0.0
# 50%              NaN  ...            0.0  4.999398e+07       0.0        0.0
# 75%              NaN  ...            0.0  7.498682e+07       0.0        0.0
# max              NaN  ...            0.0  9.999974e+07       0.0        0.0
#
#            lang        lang_lm  current_month_verification  srv_session_id  \
# count  460176.0  460176.000000               460176.000000             0.0
# mean        1.0       0.043286                    0.956267             NaN
# std         0.0       0.412039                    0.204501             NaN
# min         1.0       0.000000                    0.000000             NaN
# 25%         1.0       0.000000                    1.000000             NaN
# 50%         1.0       0.000000                    1.000000             NaN
# 75%         1.0       0.000000                    1.000000             NaN
# max         1.0       8.000000                    1.000000             NaN
#
#         type_of_text       word_len
# count  460176.000000  460176.000000
# mean        1.308630       8.803666
# std         0.951183       4.275623
# min         0.000000       0.000000
# 25%         0.000000       6.000000
# 50%         2.000000       9.000000
# 75%         2.000000      11.000000
# max         2.000000      71.000000
#
# [8 rows x 22 columns]

# %%
sns.histplot(data_from_cx.word_len)
# Out:
# <AxesSubplot:xlabel='word_len', ylabel='Count'>

# %%
data_from_cx.describe()
# Out:
#           Unnamed: 0       text_id      uploaded      verified       user_id  \
# count   93402.000000  9.340200e+04  93402.000000  93402.000000  93402.000000
# mean    87487.680681  4.313887e+07      0.358547      3.181452   6730.026830
# std     46548.866992  1.615536e+05      0.479576      3.688563     16.399707
# min         0.000000  4.290829e+07      0.000000      1.000000   6715.000000
# 25%     47624.750000  4.303265e+07      0.000000      1.000000   6717.000000
# 50%     91252.500000  4.308380e+07      0.000000      1.000000   6721.000000
# 75%    126102.750000  4.318935e+07      1.000000      8.000000   6744.000000
# max    163988.000000  4.344134e+07      1.000000     18.000000   6760.000000
#
#                 tag   verified_by        length    confidence  uploaded_time  \
# count  93402.000000  93402.000000  93402.000000  93402.000000            0.0
# mean     279.167844    574.196409   4371.519539      0.711320            NaN
# std        3.708385    538.577350   2381.325375      0.077854            NaN
# min      277.000000      0.000000      0.000000      0.242651            NaN
# 25%      277.000000    169.000000   3096.000000      0.671900            NaN
# 50%      277.000000    695.000000   4104.000000      0.719747            NaN
# 75%      278.000000    803.000000   5076.000000      0.761717            NaN
# max      286.000000   5024.000000  16091.000000      0.874107            NaN
#
#        ...  pre_processed       file_id        seq_id     test_data     lang  \
# count  ...        93402.0  9.340200e+04  93402.000000  93402.000000  93402.0
# mean   ...            0.0  3.068471e+08     16.122438      0.027730      1.0
# std    ...            0.0  4.118105e+08     29.626809      0.525861      0.0
# min    ...            0.0  0.000000e+00      0.000000      0.000000      1.0
# 25%    ...            0.0  0.000000e+00      0.000000      0.000000      1.0
# 50%    ...            0.0  0.000000e+00      5.000000      0.000000      1.0
# 75%    ...            0.0  8.197667e+08     20.000000      0.000000      1.0
# max    ...            0.0  9.048468e+08    457.000000     10.000000      1.0
#
#             lang_lm  current_month_verification  srv_session_id  type_of_text  \
# count  93402.000000                93402.000000             0.0  93402.000000
# mean       0.034678                    0.539935             NaN      0.077600
# std        0.336860                    0.498405             NaN      0.386238
# min        0.000000                    0.000000             NaN      0.000000
# 25%        0.000000                    0.000000             NaN      0.000000
# 50%        0.000000                    1.000000             NaN      0.000000
# 75%        0.000000                    1.000000             NaN      0.000000
# max        8.000000                    1.000000             NaN      2.000000
#
#            word_len
# count  93402.000000
# mean      10.044485
# std        6.789485
# min        0.000000
# 25%        5.000000
# 50%        9.000000
# 75%       13.000000
# max       61.000000
#
# [8 rows x 22 columns]

# %% [markdown]
# # S2R Plot 3

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.set_style("darkgrid")

data_from_s2r_less_6 = data_from_s2r[data_from_s2r.word_len<=6]
data_from_s2r_less_6 = data_from_s2r_less_6.sample(frac=0.1, random_state=10)

data_from_s2r_greater_6_less_9 = data_from_s2r[(data_from_s2r.word_len>6) & (data_from_s2r.word_len<9)]
data_from_s2r_greater_6_less_9 = data_from_s2r_greater_6_less_9.sample(frac=0.45, random_state=14)

data_from_s2r_9 = data_from_s2r[data_from_s2r.word_len==9]
data_from_s2r_9 = data_from_s2r_9.sample(frac=0.7, random_state=14)

data_from_s2r_greater_9 = data_from_s2r[data_from_s2r.word_len>=10]

data_from_s2r_usable = pd.concat([data_from_s2r_less_6 ,data_from_s2r_greater_6_less_9 , data_from_s2r_9 ,data_from_s2r_greater_9])
sns.histplot(data_from_s2r_usable.word_len)
# Out:
# <AxesSubplot:xlabel='word_len', ylabel='Count'>

# %%
data_from_s2r_usable.describe()
# Out:
#          Unnamed: 0  Unnamed: 0.1            id        user_id  assigned  \
# count  7.416830e+05  7.416830e+05  7.416830e+05  741683.000000  741683.0
# mean   8.652766e+05  8.652766e+05  2.303556e+07  205443.277302       1.0
# std    5.787564e+05  5.787564e+05  1.435127e+06   21880.577840       0.0
# min    0.000000e+00  0.000000e+00  1.772072e+07   11618.000000       1.0
# 25%    4.101285e+05  4.101285e+05  2.179601e+07  205574.000000       1.0
# 50%    7.208010e+05  7.208010e+05  2.329857e+07  211050.000000       1.0
# 75%    1.277682e+06  1.277682e+06  2.407781e+07  215406.000000       1.0
# max    2.290119e+06  2.290119e+06  2.557554e+07  228395.000000       1.0
#
#                  tag  flag_decode      hash  verified_time  upload_time  \
# count  741683.000000     741683.0  741683.0            0.0     741683.0
# mean       42.280184          0.0       9.0            NaN          0.0
# std         5.557885          0.0       0.0            NaN          0.0
# min        37.000000          0.0       9.0            NaN          0.0
# 25%        39.000000          0.0       9.0            NaN          0.0
# 50%        39.000000          0.0       9.0            NaN          0.0
# 75%        51.000000          0.0       9.0            NaN          0.0
# max        52.000000          0.0       9.0            NaN          0.0
#
#        uploaded  verified         synced  last_modifed    length  \
# count  741683.0  741683.0  741683.000000           0.0  741683.0
# mean        1.0      20.0       0.995358           NaN       0.0
# std         0.0       0.0       0.067975           NaN       0.0
# min         1.0      20.0       0.000000           NaN       0.0
# 25%         1.0      20.0       1.000000           NaN       0.0
# 50%         1.0      20.0       1.000000           NaN       0.0
# 75%         1.0      20.0       1.000000           NaN       0.0
# max         1.0      20.0       1.000000           NaN       0.0
#
#             word_len
# count  741683.000000
# mean        8.651791
# std         3.286517
# min         1.000000
# 25%         7.000000
# 50%         9.000000
# 75%        11.000000
# max        31.000000

# %%
fig, axs = plt.subplots(1,2)

fig.tight_layout()
fig.set_figheight(20)
fig.set_figwidth(40)

sns.histplot(data_from_cx.word_len, color ="green", label="cx",  ax=axs[0])
axs[0].legend(loc="upper left")
sns.histplot(data_from_s2r_usable.word_len, color ="red", label="s2r",  ax=axs[0])
axs[0].legend(loc="upper left")

sns.histplot(data_from_cx.word_len, color ="green", label="cx",  ax=axs[1])
axs[1].legend(loc="upper left")
sns.histplot(data_from_transcribe_usable.word_len, color ="red", label="transcribe",  ax=axs[1])
axs[1].legend(loc="upper left")

# %%
data_from_cx.describe()
# Out:
#           Unnamed: 0       text_id      uploaded      verified       user_id  \
# count   93402.000000  9.340200e+04  93402.000000  93402.000000  93402.000000
# mean    87487.680681  4.313887e+07      0.358547      3.181452   6730.026830
# std     46548.866992  1.615536e+05      0.479576      3.688563     16.399707
# min         0.000000  4.290829e+07      0.000000      1.000000   6715.000000
# 25%     47624.750000  4.303265e+07      0.000000      1.000000   6717.000000
# 50%     91252.500000  4.308380e+07      0.000000      1.000000   6721.000000
# 75%    126102.750000  4.318935e+07      1.000000      8.000000   6744.000000
# max    163988.000000  4.344134e+07      1.000000     18.000000   6760.000000
#
#                 tag   verified_by        length    confidence  uploaded_time  \
# count  93402.000000  93402.000000  93402.000000  93402.000000            0.0
# mean     279.167844    574.196409   4371.519539      0.711320            NaN
# std        3.708385    538.577350   2381.325375      0.077854            NaN
# min      277.000000      0.000000      0.000000      0.242651            NaN
# 25%      277.000000    169.000000   3096.000000      0.671900            NaN
# 50%      277.000000    695.000000   4104.000000      0.719747            NaN
# 75%      278.000000    803.000000   5076.000000      0.761717            NaN
# max      286.000000   5024.000000  16091.000000      0.874107            NaN
#
#        ...  pre_processed       file_id        seq_id     test_data     lang  \
# count  ...        93402.0  9.340200e+04  93402.000000  93402.000000  93402.0
# mean   ...            0.0  3.068471e+08     16.122438      0.027730      1.0
# std    ...            0.0  4.118105e+08     29.626809      0.525861      0.0
# min    ...            0.0  0.000000e+00      0.000000      0.000000      1.0
# 25%    ...            0.0  0.000000e+00      0.000000      0.000000      1.0
# 50%    ...            0.0  0.000000e+00      5.000000      0.000000      1.0
# 75%    ...            0.0  8.197667e+08     20.000000      0.000000      1.0
# max    ...            0.0  9.048468e+08    457.000000     10.000000      1.0
#
#             lang_lm  current_month_verification  srv_session_id  type_of_text  \
# count  93402.000000                93402.000000             0.0  93402.000000
# mean       0.034678                    0.539935             NaN      0.077600
# std        0.336860                    0.498405             NaN      0.386238
# min        0.000000                    0.000000             NaN      0.000000
# 25%        0.000000                    0.000000             NaN      0.000000
# 50%        0.000000                    1.000000             NaN      0.000000
# 75%        0.000000                    1.000000             NaN      0.000000
# max        8.000000                    1.000000             NaN      2.000000
#
#            word_len
# count  93402.000000
# mean      10.044485
# std        6.789485
# min        0.000000
# 25%        5.000000
# 50%        9.000000
# 75%       13.000000
# max       61.000000
#
# [8 rows x 22 columns]
