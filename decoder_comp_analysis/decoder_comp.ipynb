# %%
import numpy as np
import seaborn as sns
import os
from matplotlib import pyplot as plt
sns.set_style("darkgrid")
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
cpp_smax = np.array([float(x) for x in open("/home/suryansh.tiwari/smax_decomp/decompressed_server_smax.txt").readlines()])
py_smax = np.array([float(x) for x in open("/home/suryansh.tiwari/smax_decomp/decompressed_smax.txt").readlines()])
orig_smax = np.array([float(x) for x in open("/home/suryansh.tiwari/smax_decomp/original_smax.txt").readlines()])

# %%
sns.heatmap(orig_smax.reshape(int(len(cpp_smax)/73), 73), label="orig_smax")
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(cpp_smax.reshape(int(len(cpp_smax)/73), 73), label="cpp_smax")
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(py_smax.reshape(int(len(py_smax)/73), 73), label="py_smax")
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(((cpp_smax - py_smax)**2).reshape(int(len(cpp_smax)/73), 73), label="cpp_smax")
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(((cpp_smax - py_smax)).reshape(int(len(cpp_smax)/73), 73), label="cpp_smax")
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(((orig_smax - py_smax)).reshape(int(len(cpp_smax)/73), 73), label="cpp_smax")
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(((orig_smax - cpp_smax)).reshape(int(len(cpp_smax)/73), 73), label="cpp_smax")
# Out:
# <AxesSubplot:>

# %%
cpp_smax - py_smax
# Out:
# array([-3.00349e-08, -3.00349e-08, -3.00349e-08, ..., -3.00349e-08,
#        -3.00349e-08, -3.00349e-08])

# %%
np.max(cpp_smax - py_smax) < 1e-07
# Out:
# True

# %%
np.max(cpp_smax - py_smax)
# Out:
# -3.0034899999378806e-08

# %%
((cpp_smax - py_smax)**2).mean()
# Out:
# 9.020952179726853e-16

# %%
cpp_smax
# Out:
# array([0.00518413, 0.00928565, 0.0195012 , ..., 0.00599682, 0.0185089 ,
#        0.0165038 ])

# %%
py_smax
# Out:
# array([0.00518413, 0.00928565, 0.01950124, ..., 0.00599682, 0.01850893,
#        0.01650378])

# %%
cpp_smax - orig_smax
np.max(cpp_smax - orig_smax)
# Out:
# -3.0034899999378806e-08
