# %%
import pandas as pd
import seaborn as sns

# %%
na_ol_more = pd.read_csv(filepath_or_buffer="/shared/suryansh.tiwari/output_csv/Redo_HI_FA_EP6_all_vs_data.csv")
na_ol_less = pd.read_csv(filepath_or_buffer="")

# %%
na_ol_more.describe()
# Out:
#             Text_id        GT_len    Total_edit           WER    WER*GT_len  \
# count  2.762400e+04  27624.000000  27624.000000  27624.000000  27624.000000
# mean   4.559855e+07      3.693781      0.755502      0.197606      0.747068
# std    3.028433e+05      2.612177      1.500614      0.311076      1.489222
# min    4.462708e+07      1.000000      0.000000      0.000000      0.000000
# 25%    4.542283e+07      2.000000      0.000000      0.000000      0.000000
# 50%    4.555051e+07      3.000000      0.000000      0.000000      0.000000
# 75%    4.573235e+07      5.000000      1.000000      0.333333      1.000000
# max    4.609982e+07     40.000000     34.000000      1.000000     34.000000
#
#         GT_char_len  Total_char_edit           CER  CER*GT_char_len  \
# count  27624.000000     27624.000000  27624.000000     27624.000000
# mean      49.474334         3.792427      0.072766         3.787504
# std       31.822084         9.691199      0.155056         9.677320
# ...

# %%
na_ol_less.describe()
# Out:
#             Text_id        GT_len    Total_edit           WER    WER*GT_len  \
# count  2.481700e+04  24817.000000  24817.000000  24817.000000  24817.000000
# mean   4.558721e+07      3.712254      0.730145      0.192100      0.723577
# std    3.007276e+05      2.629819      1.449807      0.301673      1.441975
# min    4.462708e+07      1.000000      0.000000      0.000000      0.000000
# 25%    4.536304e+07      2.000000      0.000000      0.000000      0.000000
# 50%    4.555020e+07      3.000000      0.000000      0.000000      0.000000
# 75%    4.573191e+07      5.000000      1.000000      0.333333      1.000000
# max    4.609982e+07     40.000000     34.000000      1.000000     34.000000
#
#         GT_char_len  Total_char_edit           CER  CER*GT_char_len  \
# count  24817.000000     24817.000000  24817.000000     24817.000000
# mean      49.597574         3.345046      0.063289         3.342709
# std       32.024788         8.288530      0.124593         8.283000
# ...

# %%
na_ol_more_ti = set(na_ol_more.Text_id)
na_ol_less_ti = set(na_ol_less.Text_id)
intersec = na_ol_more_ti.intersection(na_ol_less_ti)
diff = na_ol_more_ti.difference(na_ol_less_ti)

# %%
more = na_ol_more.loc[na_ol_more['Text_id'].isin(intersec)]
less = na_ol_less.loc[na_ol_less['Text_id'].isin(intersec)]

# %%
#more = more[['Text_id', 'Machine_Transcribed_text', 'WER']]
#less = less[['Text_id', 'Machine_Transcribed_text' , 'WER']]

# %%
z_intersection = pd.merge(more, less, on='Text_id', how='inner')

# %%
z_intersection.head()
# Out:
#     Tag_x   Text_id                      Type_of_text_x  \
# 0  week32  44627083                primary_speaker_only
# 1  week32  44627089  multi_speaker_replaced_by_wildcard
# 2  week32  44627090                primary_speaker_only
# 3  week32  44627093                primary_speaker_only
# 4  week32  44627094                primary_speaker_only
#
#                                             Raw_GT_x  \
# 0                                            कमर चेन
# 1                         कीपैड फोन सबसे सस्ता @ _ @
# 2  टॉप एंड पैंट नाइन इयर्स नाइन एंड टेन इयर्स ओल्...
# 3                                       ऑडेन की रजाई
# 4                                         लेडीज पर्स
#
#                                                 GT_x  \
# 0                                            कमर चेन
# 1                            कीपैड फोन सबसे सस्ता  _
# 2  टॉप एंड पैंट नाइन इयर्स नाइन एंड टेन इयर्स ओल्...
# 3                                       ऑडेन की रजाई
# ...

# %%
z_intersection['match_text'] = z_intersection['Machine_Transcribed_text_x'] == z_intersection['Machine_Transcribed_text_y']

# %%
z_intersection.match_text.value_counts()
# Out:
# True     24310
# False      564
# Name: match_text, dtype: int64

# %%
z_intersection.loc[z_intersection['match_text'] == False]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d49527bf33b3> in <module>
# ----> 1 z_intersection.loc[z_intersection['match_text'] == False]
#
# NameError: name 'z_intersection' is not defined

# %%
z_diff = na_ol_more[na_ol_more.Text_id.isin(diff)]

# %%
z_diff

# %%
print(z_diff['confidence'].describe())
sns.distplot(z_diff['confidence'])
# Out:
# count    2750.000000
# mean        0.703571
# std         0.101848
# min         0.000000
# 25%         0.653245
# 50%         0.722212
# 75%         0.773123
# max         0.874107
# Name: confidence, dtype: float64
# <AxesSubplot:xlabel='confidence'>

# %%
print(na_ol_less['confidence'].describe())
sns.distplot(na_ol_less['confidence'])
# Out:
# count    24817.000000
# mean         0.697307
# std          0.103192
# min          0.000000
# 25%          0.643731
# 50%          0.716264
# 75%          0.771360
# max          0.874107
# Name: confidence, dtype: float64
# <AxesSubplot:xlabel='confidence'>

# %%
print(na_ol_more['confidence'].describe())
sns.distplot(na_ol_more['confidence'])
# Out:
# count    27624.000000
# mean         0.696790
# std          0.105023
# min          0.000000
# 25%          0.642857
# 50%          0.716305
# 75%          0.771499
# max          0.874107
# Name: confidence, dtype: float64
# <AxesSubplot:xlabel='confidence'>

# %%
z_intersection.describe()
# Out:
#             Text_id      GT_len_x  Total_edit_x         WER_x  WER*GT_len_x  \
# count  2.487400e+04  24874.000000  24874.000000  24874.000000  24874.000000
# mean   4.558691e+07      3.713074      0.764694      0.198673      0.756493
# std    3.005603e+05      2.629030      1.521998      0.311747      1.511266
# min    4.462708e+07      1.000000      0.000000      0.000000      0.000000
# 25%    4.536304e+07      2.000000      0.000000      0.000000      0.000000
# 50%    4.555019e+07      3.000000      0.000000      0.000000      0.000000
# 75%    4.573189e+07      5.000000      1.000000      0.333333      1.000000
# max    4.609982e+07     40.000000     34.000000      1.000000     34.000000
#
#        GT_char_len_x  Total_char_edit_x         CER_x  CER*GT_char_len_x  \
# count   24874.000000       24874.000000  24874.000000       24874.000000
# mean       49.697033           3.832596      0.072856           3.828094
# ...

# %%
na_ol_more.describe()
# Out:
#             Text_id        GT_len    Total_edit           WER    WER*GT_len  \
# count  2.762400e+04  27624.000000  27624.000000  27624.000000  27624.000000
# mean   4.559855e+07      3.693781      0.755502      0.197606      0.747068
# std    3.028433e+05      2.612177      1.500614      0.311076      1.489222
# min    4.462708e+07      1.000000      0.000000      0.000000      0.000000
# 25%    4.542283e+07      2.000000      0.000000      0.000000      0.000000
# 50%    4.555051e+07      3.000000      0.000000      0.000000      0.000000
# 75%    4.573235e+07      5.000000      1.000000      0.333333      1.000000
# max    4.609982e+07     40.000000     34.000000      1.000000     34.000000
#
#         GT_char_len  Total_char_edit           CER  CER*GT_char_len  \
# count  27624.000000     27624.000000  27624.000000     27624.000000
# mean      49.474334         3.792427      0.072766         3.787504
# std       31.822084         9.691199      0.155056         9.677320
# ...

# %%
na_ol_less.describe()
# Out:
#             Text_id        GT_len    Total_edit           WER    WER*GT_len  \
# count  2.481700e+04  24817.000000  24817.000000  24817.000000  24817.000000
# mean   4.558721e+07      3.712254      0.730145      0.192100      0.723577
# std    3.007276e+05      2.629819      1.449807      0.301673      1.441975
# min    4.462708e+07      1.000000      0.000000      0.000000      0.000000
# 25%    4.536304e+07      2.000000      0.000000      0.000000      0.000000
# 50%    4.555020e+07      3.000000      0.000000      0.000000      0.000000
# 75%    4.573191e+07      5.000000      1.000000      0.333333      1.000000
# max    4.609982e+07     40.000000     34.000000      1.000000     34.000000
#
#         GT_char_len  Total_char_edit           CER  CER*GT_char_len  \
# count  24817.000000     24817.000000  24817.000000     24817.000000
# mean      49.597574         3.345046      0.063289         3.342709
# std       32.024788         8.288530      0.124593         8.283000
# ...

# %%
print(z_diff.describe())
sns.pairplot(z_diff[['GT_len', 'Total_edit', 'WER', 'WER*GT_len', 'GT_char_len', 'Total_char_edit']])
# Out:
#             Text_id       GT_len   Total_edit          WER   WER*GT_len  \
# count  2.750000e+03  2750.000000  2750.000000  2750.000000  2750.000000
# mean   4.570381e+07     3.519273     0.672364     0.187952     0.661818
# std    3.031534e+05     2.448040     1.288475     0.304827     1.269660
# min    4.489503e+07     1.000000     0.000000     0.000000     0.000000
# 25%    4.548444e+07     2.000000     0.000000     0.000000     0.000000
# 50%    4.572680e+07     3.000000     0.000000     0.000000     0.000000
# 75%    4.603114e+07     4.000000     1.000000     0.333333     1.000000
# max    4.609981e+07    22.000000    19.000000     1.000000    19.000000
#
#        GT_char_len  Total_char_edit          CER  CER*GT_char_len   confidence
# count  2750.000000      2750.000000  2750.000000      2750.000000  2750.000000
# mean     47.460000         3.429091     0.071954         3.420364     0.703571
# std      29.876422         8.899415     0.159008         8.872322     0.101848
# ...

# %%
sns.distplot(z_diff['Total_edit'])
# Out:
# <AxesSubplot:xlabel='Total_edit'>

# %%
na_ol_less_sample = na_ol_less.sample(n=2750)
na_ol_less_sample.describe()
sns.pairplot(na_ol_less_sample[['GT_len', 'Total_edit', 'WER', 'WER*GT_len', 'GT_char_len', 'Total_char_edit']])

# %%
na_ol_more_sample = na_ol_more.sample(n=2750)
na_ol_more_sample.describe()
sns.pairplot(na_ol_more_sample[['GT_len', 'Total_edit', 'WER', 'WER*GT_len', 'GT_char_len', 'Total_char_edit']])
