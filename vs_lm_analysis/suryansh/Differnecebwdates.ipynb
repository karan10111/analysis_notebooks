# %%
import pandas as pd
import seaborn as sns

# %%
oct_all_data = pd.read_csv('/shared/suryansh.tiwari/output_csv/HI_FA_2_reverified_10k_new_dataset.csv')

# %%
week40_data = pd.read_csv('/shared/suryansh.tiwari/output_csv/HI_FA_2_voice_search_5th_oct.csv')

# %%
oct_all_data.shape, week40_data.shape
# Out:
# ((19996, 22), (13206, 21))

# %%
oct_all_data = oct_all_data[(oct_all_data.Type_of_text == 'multi_speaker_replaced_by_blank') | (oct_all_data.Type_of_text == 'primary_speaker_with_wildcard')]

# %%
week40_data = week40_data[(week40_data.Type_of_text == 'multi_speaker_replaced_by_blank') | (week40_data.Type_of_text == 'primary_speaker_with_wildcard')]

# %%
oct_all_data.shape, week40_data.shape
# Out:
# ((9998, 22), (6603, 21))

# %%
sns.scatterplot(x = oct_all_data['GT_len'], y = oct_all_data['WER'])
# sns.pairplot(oct_all_data, hue="GT_len")
# Out:
# <AxesSubplot:xlabel='GT_len', ylabel='WER'>

# %%
sns.scatterplot(x = week40_data['GT_len'], y = week40_data['WER'])
# Out:
# <AxesSubplot:xlabel='GT_len', ylabel='WER'>

# %%
sns.histplot(oct_all_data['confidence'], color='blue')
sns.histplot(week40_data['confidence'], color='green')
# Out:
# <AxesSubplot:xlabel='confidence', ylabel='Count'>

# %%
sns.kdeplot(x = week40_data['GT_len'], y = week40_data['WER'])
# Out:
# <AxesSubplot:xlabel='GT_len', ylabel='WER'>

# %%
sns.kdeplot(x = oct_all_data['GT_len'], y = oct_all_data['WER'])
# Out:
# <AxesSubplot:xlabel='GT_len', ylabel='WER'>

# %%
sns.jointplot(x = week40_data['GT_len'], y = week40_data['WER'],color='green')
sns.jointplot(x = oct_all_data['GT_len'], y = oct_all_data['WER'],color='blue')

# %%
sns.jointplot(x = week40_data['confidence'], y = week40_data['WER'],color='green')
sns.jointplot(x = oct_all_data['confidence'], y = oct_all_data['WER'],color='blue')

# %%
week40_data.confidence.min()
week40_data[week40_data.confidence<=0.3].head()
# Out:
#        Tag   Text_id                     Type_of_text  \
# 1619   287  47837607  multi_speaker_replaced_by_blank
# 4929   287  47841174  multi_speaker_replaced_by_blank
# 8585   287  47903651  multi_speaker_replaced_by_blank
# 12737  287  47906171  multi_speaker_replaced_by_blank
#
#                                          Raw_GT                            GT  \
# 1619       एक @ _ @ गुड़िया रुक चिड़िया _ @ _ @    एक   गुड़िया रुक चिड़िया _
# 4929          _ @ _ @ _ मोबाइल _ दिला दिया था _  _    मोबाइल _ दिला दिया था _
# 8585               _ नेट खत्म कर रही हो @ _ @ _      _ नेट खत्म कर रही हो   _
# 12737  _ वो दिल्ली से _ @ _ रखता है _ @ _ @ _ @              _ वो दिल्ली से _
#
#                       GT(english) utf_text          Machine_Transcribed_text  \
# 1619      ek gudiya ruk चिड़िया _      NaN                  जोगिया यार्डले
# 4929   _ mobile _ dila diya tha _      NaN                किताबनामा पड़ेगा
# ...

# %%
s = week40_data[week40_data.GT_len<='30'].head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-13d286723583> in <module>
# ----> 1 s = week40_data[week40_data.GT_len<='30'].head()
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/core/ops/__init__.py in wrapper(self, other)
#     368         rvalues = extract_array(other, extract_numpy=True)
#     369
# --> 370         res_values = comparison_op(lvalues, rvalues, op)
#     371
#     372         return self._construct_result(res_values, name=res_name)
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/core/ops/array_ops.py in comparison_op(left, right, op)
# ...

# %%
sns.jointplot(x = week40_data[week40_data.GT_len<='30'], y = week40_data['WER*GT_len'],color='green')
sns.jointplot(x = oct_all_data[oct_all_data.GT_len<='30'], y = oct_all_data[oct_all_data['WER*GT_len']],color='blue')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-80-7a5a17c7c126> in <module>
# ----> 1 sns.jointplot(x = week40_data[week40_data.GT_len<='30'], y = week40_data['WER*GT_len'],color='green')
#       2 sns.jointplot(x = oct_all_data[oct_all_data.GT_len<='30'], y = oct_all_data[oct_all_data['WER*GT_len']],color='blue')
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/core/ops/__init__.py in wrapper(self, other)
#     368         rvalues = extract_array(other, extract_numpy=True)
#     369
# --> 370         res_values = comparison_op(lvalues, rvalues, op)
#     371
# ...
