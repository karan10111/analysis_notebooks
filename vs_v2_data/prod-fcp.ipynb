# %%
import pandas as pd
import seaborn as sns

sns.set_style("darkgrid")
sns.set(rc={'figure.figsize':(11.7,8.27)})

from matplotlib import pyplot as plt

# %% [markdown]
# # Get Data

# %%
baseline = pd.read_csv("/shared/suryansh.tiwari/output_csv/VS_BASE_2_voice_search_5th_oct.csv")  # baseline
baseline_grocery = pd.read_csv("/shared/karan.verma/fcp_output_files/5_oct_HI.txt")

ep_5000_0_tf = pd.read_csv("/shared/suryansh.tiwari/output_csv/VS_5000_2_voice_search_5th_oct.csv")  
ep_1_prod = pd.read_csv("/shared/suryansh.tiwari/output_csv/VS_4999_2_voice_search_5th_oct.csv")  

ep_10000_0_tf = pd.read_csv("/shared/suryansh.tiwari/output_csv/VS_10000_2_voice_search_5th_oct.csv") 
ep_2_prod = pd.read_csv("/shared/suryansh.tiwari/output_csv/VS_9999_2_voice_search_5th_oct.csv") 

ep_15000_tf = pd.read_csv("/shared/karan.verma/fcp_outputs/5_oct_15000.txt")
ep_3_prod = pd.read_csv("/shared/karan.verma/fcp_outputs/5_oct_14999.txt")

ep_20000_tf = pd.read_csv("/shared/karan.verma/fcp_output_files//5_oct_20000.txt")
ep_4_prod = pd.read_csv("/shared/karan.verma/fcp_output_files//5_oct_19999.txt")

ep_25000_tf = pd.read_csv("/shared/karan.verma/fcp_output_files/5_oct_25000.txt")
ep_5_prod = pd.read_csv("/shared/karan.verma/fcp_output_files/5_oct_24999.txt")

ep_6_tf = pd.read_csv("/shared/karan.verma/fcp_output_files/5_oct_VS_256BS_6.txt")
ep_6_5_tf = pd.read_csv("/shared/karan.verma/fcp_output_files/5_oct_VS_256BS_6_5.txt")

prod = pd.read_csv("/shared/suryansh.tiwari/output_csv/HI_FA_2_voice_search_5th_oct.csv") # Current Prod

# %%
prod_wer = (prod.groupby(by="Type_of_text")["WER*GT_len"].agg('sum')/prod.groupby(by="Type_of_text")["GT_len"].agg('sum')).reset_index()
prod_wer.columns = [['Type_of_text', "wer"]]
prod_wer
# Out:
#                          Type_of_text       wer
# 0     multi_speaker_replaced_by_blank  0.209641
# 1  multi_speaker_replaced_by_wildcard  0.141445
# 2   primary_speaker_replaced_by_blank  0.136555
# 3       primary_speaker_with_wildcard  0.108601

# %% [markdown]
# # WER/CER

# %% [markdown]
# #### Baseline WER

# %%
baseline_wer = (baseline.groupby(by="Type_of_text")["WER*GT_len"].agg('sum')/baseline.groupby(by="Type_of_text")["GT_len"].agg('sum')).reset_index()
baseline_wer.columns = [['Type_of_text', "wer"]]
baseline_wer
# Out:
#                          Type_of_text       wer
# 0     multi_speaker_replaced_by_blank  0.301675
# 1  multi_speaker_replaced_by_wildcard  0.198476
# 2   primary_speaker_replaced_by_blank  0.193288
# 3       primary_speaker_with_wildcard  0.165746

# %%
baseline_grocery_wer = (baseline_grocery.groupby(by="Type_of_text")["WER*GT_len"].agg('sum')/baseline_grocery.groupby(by="Type_of_text")["GT_len"].agg('sum')).reset_index()
baseline_grocery_wer.columns = [['Type_of_text', "wer"]]
baseline_grocery_wer
# Out:
#                          Type_of_text       wer
# 0     multi_speaker_replaced_by_blank  0.414605
# 1  multi_speaker_replaced_by_wildcard  0.297978
# 2   primary_speaker_replaced_by_blank  0.291911
# 3       primary_speaker_with_wildcard  0.266760

# %% [markdown]
# ### TF 5k Steps, 1st Epoch WER

# %%
ep_5000_0_tf_wer = (ep_5000_0_tf.groupby(by="Type_of_text")["WER*GT_len"].agg('sum')/ep_5000_0_tf.groupby(by="Type_of_text")["GT_len"].agg('sum')).reset_index()
ep_5000_0_tf_wer.columns = [['Type_of_text', "wer"]]
ep_5000_0_tf_wer
# Out:
#                          Type_of_text       wer
# 0     multi_speaker_replaced_by_blank  0.297148
# 1  multi_speaker_replaced_by_wildcard  0.195459
# 2   primary_speaker_replaced_by_blank  0.194937
# 3       primary_speaker_with_wildcard  0.168302

# %% [markdown]
# ### Theano 1st epoch WER

# %%
ep_1_prod_wer = (ep_1_prod.groupby(by="Type_of_text")["WER*GT_len"].agg('sum')/ep_1_prod.groupby(by="Type_of_text")["GT_len"].agg('sum')).reset_index()
ep_1_prod_wer.columns = [['Type_of_text', "wer"]]
ep_1_prod_wer
# Out:
#                          Type_of_text       wer
# 0     multi_speaker_replaced_by_blank  0.264413
# 1  multi_speaker_replaced_by_wildcard  0.198913
# 2   primary_speaker_replaced_by_blank  0.193535
# 3       primary_speaker_with_wildcard  0.167972

# %% [markdown]
# ### TF 10k Steps, 2nd Epoch WER

# %%
ep_10000_0_tf_wer = (ep_10000_0_tf.groupby(by="Type_of_text")["WER*GT_len"].agg('sum')/ep_10000_0_tf.groupby(by="Type_of_text")["GT_len"].agg('sum')).reset_index()
ep_10000_0_tf_wer.columns = [['Type_of_text', "wer"]]
ep_10000_0_tf_wer
# Out:
#                          Type_of_text       wer
# 0     multi_speaker_replaced_by_blank  0.277912
# 1  multi_speaker_replaced_by_wildcard  0.182257
# 2   primary_speaker_replaced_by_blank  0.177455
# 3       primary_speaker_with_wildcard  0.150738

# %% [markdown]
# ### Theano 2nd epoch WER

# %%
ep_2_prod_wer = (ep_2_prod.groupby(by="Type_of_text")["WER*GT_len"].agg('sum')/ep_2_prod.groupby(by="Type_of_text")["GT_len"].agg('sum')).reset_index()
ep_2_prod_wer.columns = [['Type_of_text', "wer"]]
ep_2_prod_wer
# Out:
#                          Type_of_text       wer
# 0     multi_speaker_replaced_by_blank  0.242077
# 1  multi_speaker_replaced_by_wildcard  0.177860
# 2   primary_speaker_replaced_by_blank  0.173540
# 3       primary_speaker_with_wildcard  0.146981

# %% [markdown]
# ### TF 15k Steps, 3rd Epoch WER

# %%
ep_15000_tf_wer = (ep_15000_tf.groupby(by="Type_of_text")["WER*GT_len"].agg('sum')/ep_15000_tf.groupby(by="Type_of_text")["GT_len"].agg('sum')).reset_index()
ep_15000_tf_wer.columns = [['Type_of_text', "wer"]]
ep_15000_tf_wer
# Out:
#                          Type_of_text       wer
# 0     multi_speaker_replaced_by_blank  0.270594
# 1  multi_speaker_replaced_by_wildcard  0.177731
# 2   primary_speaker_replaced_by_blank  0.172095
# 3       primary_speaker_with_wildcard  0.145378

# %% [markdown]
# ### Theano 3rd epoch WER

# %%
ep_3_prod_wer = (ep_3_prod.groupby(by="Type_of_text")["WER*GT_len"].agg('sum')/ep_3_prod.groupby(by="Type_of_text")["GT_len"].agg('sum')).reset_index()
ep_3_prod_wer.columns = [['Type_of_text', "wer"]]
ep_3_prod_wer
# Out:
#                          Type_of_text       wer
# 0     multi_speaker_replaced_by_blank  0.237775
# 1  multi_speaker_replaced_by_wildcard  0.171521
# 2   primary_speaker_replaced_by_blank  0.163849
# 3       primary_speaker_with_wildcard  0.136060

# %% [markdown]
# ### TF 4th

# %%
ep_20000_tf_wer = (ep_20000_tf.groupby(by="Type_of_text")["WER*GT_len"].agg('sum')/ep_20000_tf.groupby(by="Type_of_text")["GT_len"].agg('sum')).reset_index()
ep_20000_tf_wer.columns = [['Type_of_text', "wer"]]
ep_20000_tf_wer
# Out:
#                          Type_of_text       wer
# 0     multi_speaker_replaced_by_blank  0.269524
# 1  multi_speaker_replaced_by_wildcard  0.174677
# 2   primary_speaker_replaced_by_blank  0.171930
# 3       primary_speaker_with_wildcard  0.144141

# %% [markdown]
# #### Theano 4th

# %%
ep_4_prod_wer = (ep_4_prod.groupby(by="Type_of_text")["WER*GT_len"].agg('sum')/ep_4_prod.groupby(by="Type_of_text")["GT_len"].agg('sum')).reset_index()
ep_4_prod_wer.columns = [['Type_of_text', "wer"]]
ep_4_prod_wer
# Out:
#                          Type_of_text       wer
# 0     multi_speaker_replaced_by_blank  0.230154
# 1  multi_speaker_replaced_by_wildcard  0.161485
# 2   primary_speaker_replaced_by_blank  0.158572
# 3       primary_speaker_with_wildcard  0.129958

# %% [markdown]
# ### TF 5th

# %%
ep_25000_tf_wer = (ep_25000_tf.groupby(by="Type_of_text")["WER*GT_len"].agg('sum')/ep_25000_tf.groupby(by="Type_of_text")["GT_len"].agg('sum')).reset_index()
ep_25000_tf_wer.columns = [['Type_of_text', "wer"]]
ep_25000_tf_wer
# Out:
#                          Type_of_text       wer
# 0     multi_speaker_replaced_by_blank  0.256904
# 1  multi_speaker_replaced_by_wildcard  0.168100
# 2   primary_speaker_replaced_by_blank  0.167560
# 3       primary_speaker_with_wildcard  0.140595

# %% [markdown]
# ## Theano 5th

# %%
ep_5_prod_wer = (ep_5_prod.groupby(by="Type_of_text")["WER*GT_len"].agg('sum')/ep_5_prod.groupby(by="Type_of_text")["GT_len"].agg('sum')).reset_index()
ep_5_prod_wer.columns = [['Type_of_text', "wer"]]
ep_5_prod_wer
# Out:
#                          Type_of_text       wer
# 0     multi_speaker_replaced_by_blank  0.222113
# 1  multi_speaker_replaced_by_wildcard  0.154264
# 2   primary_speaker_replaced_by_blank  0.151892
# 3       primary_speaker_with_wildcard  0.124598

# %% [markdown]
# ### TF 6th

# %%
ep_6_tf_wer = (ep_6_tf.groupby(by="Type_of_text")["WER*GT_len"].agg('sum')/ep_6_tf.groupby(by="Type_of_text")["GT_len"].agg('sum')).reset_index()
ep_6_tf_wer.columns = [['Type_of_text', "wer"]]
ep_6_tf_wer
# Out:
#                          Type_of_text       wer
# 0     multi_speaker_replaced_by_blank  0.265691
# 1  multi_speaker_replaced_by_wildcard  0.172526
# 2   primary_speaker_replaced_by_blank  0.167725
# 3       primary_speaker_with_wildcard  0.140018

# %% [markdown]
# ### TF 6.5th

# %%
ep_6_5_tf_wer = (ep_6_5_tf.groupby(by="Type_of_text")["WER*GT_len"].agg('sum')/ep_6_5_tf.groupby(by="Type_of_text")["GT_len"].agg('sum')).reset_index()
ep_6_5_tf_wer.columns = [['Type_of_text', "wer"]]
ep_6_5_tf_wer
# Out:
#                          Type_of_text       wer
# 0     multi_speaker_replaced_by_blank  0.261467
# 1  multi_speaker_replaced_by_wildcard  0.170489
# 2   primary_speaker_replaced_by_blank  0.167890
# 3       primary_speaker_with_wildcard  0.139688

# %% [markdown]
# # Merging 4th of TF and Theano

# %%
merged_4th = pd.merge(ep_20000_tf, ep_4_prod, how='inner', on=['Text_id', 'Type_of_text'])

# %%
merged_4th
# Out:
#        Tag_x   Text_id                        Type_of_text  \
# 0        287  44554384       primary_speaker_with_wildcard
# 1        287  44554384   primary_speaker_replaced_by_blank
# 2        287  44554469  multi_speaker_replaced_by_wildcard
# 3        287  44554469     multi_speaker_replaced_by_blank
# 4        287  44554478       primary_speaker_with_wildcard
# ...      ...       ...                                 ...
# 13197    287  47906412   primary_speaker_replaced_by_blank
# 13198    287  47906413  multi_speaker_replaced_by_wildcard
# 13199    287  47906413     multi_speaker_replaced_by_blank
# 13200    287  47906414       primary_speaker_with_wildcard
# 13201    287  47906414   primary_speaker_replaced_by_blank
#
#                                          Raw_GT_x  \
# 0                         प्लैटिना का शॉकर प्राइज
# 1                         प्लैटिना का शॉकर प्राइज
# 2      @ _ @ पाँच सौ रूप्या में टॉप और जींस लेडीज
# 3      @ _ @ पाँच सौ रूप्या में टॉप और जींस लेडीज
# ...

# %%
merged_4th[(merged_4th.Type_of_text == 'multi_speaker_replaced_by_blank') & (merged_4th.Machine_Transcribed_text_x == merged_4th.Machine_Transcribed_text_y) ][['Machine_Transcribed_text_x', 'Machine_Transcribed_text_y']]
# Out:
#                        Machine_Transcribed_text_x  \
# 7            शर्ट दिखाइए दोनों पट्टी पहनने वाला
# 11                              जींस टॉप दिखाइए
# 29                                 ओप्पो ए फाइव
# 33         पबजी टी शर्ट ग्यारह साल के बच्चों की
# 43     कंपोनेंट बैक कवर ओप्पो ए नाइन टू ट्वेंटी
# ...                                           ...
# 13159                         रजनीगंधा का पैकेट
# 13173                हाथ पे चिपकाने वाला स्टीकर
# 13177               कॉफी कप जिसमें खुशी लिखा हो
# 13191                                 अप्पे पैन
# 13195                          लेडीज किड्स वियर
#
#                        Machine_Transcribed_text_y
# 7            शर्ट दिखाइए दोनों पट्टी पहनने वाला
# 11                              जींस टॉप दिखाइए
# 29                                 ओप्पो ए फाइव
# 33         पबजी टी शर्ट ग्यारह साल के बच्चों की
# 43     कंपोनेंट बैक कवर ओप्पो ए नाइन टू ट्वेंटी
# ...                                           ...
# ...

# %%
merged_4th[(merged_4th.Type_of_text == 'multi_speaker_replaced_by_blank') & (merged_4th.Machine_Transcribed_text_x != merged_4th.Machine_Transcribed_text_y) ][['Machine_Transcribed_text_x', 'Machine_Transcribed_text_y']]
# Out:
#                                                                                Machine_Transcribed_text_x  \
# 3                                                                     पाँच सौ रुपये में टॉपर जींस लेडीज
# 15                                                                 चार्जिंग बैक टाइटर मोट कंट्रोल कार्स
# 19                                                      फ्री चार्जिंग रिमोट कंट्रोल कार इन थाउजेंड बिलो
# 23                                                                                      काटी ओ पी इ सेट
# 25                                                                                          आई बॉल टॉयज
# ...                                                                                                   ...
# 13183                                             गूगल प्ले कार्ड का भी रह सकते हैं में अच्छे कारहांदला
# 13185                                                                  बोलने का ग्रे लेके तो करेनाहल्ली
# ...

# %%
merged_4th['tf_predicted_word_len'] = merged_4th.Machine_Transcribed_text_x.dropna().str.split().apply(len)
merged_4th['theano_predicted_word_len'] = merged_4th.Machine_Transcribed_text_y.dropna().str.split().apply(len)

# %%
sns.scatterplot(data=merged_4th[(merged_4th.Type_of_text == 'multi_speaker_replaced_by_blank') & (merged_4th.Machine_Transcribed_text_x != merged_4th.Machine_Transcribed_text_y) ] , x="tf_predicted_word_len", y="theano_predicted_word_len")
# Out:
# <AxesSubplot:xlabel='tf_predicted_word_len', ylabel='theano_predicted_word_len'>

# %%
sns.scatterplot(data=merged_4th[(merged_4th.Type_of_text == 'multi_speaker_replaced_by_blank') & (merged_4th.Machine_Transcribed_text_x == merged_4th.Machine_Transcribed_text_y) ] , x="tf_predicted_word_len", y="theano_predicted_word_len")
# Out:
# <AxesSubplot:xlabel='tf_predicted_word_len', ylabel='theano_predicted_word_len'>

# %%
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', 200)
should_be_mspeak_blank = (merged_4th.Type_of_text == 'multi_speaker_replaced_by_blank')
predicted_word_len_should_differ = (merged_4th.tf_predicted_word_len != merged_4th.theano_predicted_word_len)
tf_wer_is_lower = (merged_4th.WER_x < merged_4th.WER_y)
merged_4th[should_be_mspeak_blank &  predicted_word_len_should_differ & tf_wer_is_lower]
# Out:
#        Tag_x   Text_id                     Type_of_text  \
# 19       287  44555031  multi_speaker_replaced_by_blank
# 115      287  44627236  multi_speaker_replaced_by_blank
# 193      287  44628736  multi_speaker_replaced_by_blank
# 321      287  47350536  multi_speaker_replaced_by_blank
# 323      287  47350564  multi_speaker_replaced_by_blank
# 371      287  47350865  multi_speaker_replaced_by_blank
# 467      287  47351120  multi_speaker_replaced_by_blank
# 619      287  47351400  multi_speaker_replaced_by_blank
# 1045     287  47352045  multi_speaker_replaced_by_blank
# 1331     287  47352549  multi_speaker_replaced_by_blank
# 1553     287  47352895  multi_speaker_replaced_by_blank
# 1711     287  47837759  multi_speaker_replaced_by_blank
# 1753     287  47837848  multi_speaker_replaced_by_blank
# 1889     287  47838091  multi_speaker_replaced_by_blank
# 1981     287  47838224  multi_speaker_replaced_by_blank
# 2027     287  47838286  multi_speaker_replaced_by_blank
# ...

# %%
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', 200)
tf_wer_is_higher = (merged_4th.WER_x > merged_4th.WER_y)
tf_word_len_high = (merged_4th.tf_predicted_word_len - merged_4th.theano_predicted_word_len > 5)
merged_4th[should_be_mspeak_blank &  tf_word_len_high][['Text_id', 'Machine_Transcribed_text_x', 'Machine_Transcribed_text_y', 'WER_x', 'WER_y', 'GT_x', 'Type_of_text']]
# Out:
#         Text_id  \
# 435    47351067
# 1691   47837737
# 2123   47838419
# 3551   47839923
# 3833   47840123
# 4089   47840305
# 4343   47840505
# 5337   47841520
# 5485   47841623
# 5831   47841870
# 7295   47902954
# 7461   47903058
# 7611   47903136
# 8651   47903689
# 8771   47903751
# 8951   47903848
# 9089   47903919
# 9379   47904073
# 9641   47904209
# 9931   47904360
# 10033  47904414
# 10069  47904433
# 10641  47904734
# 10909  47904881
# 11033  47904945
# 11345  47905442
# 11741  47905649
# 12193  47905891
# 12245  47905922
# 12687  47906148
# 12733  47906171
# 12917  47906266
#
#                                                                                                               Machine_Transcribed_text_x  \
# 435                       क्या स्टाइलिश टी शर्ट है वह तो आ जाएंगे लेकिन भाई उसको पहन के लिख लेगा आदमी क्या गारेंटी जो लाया था जायेगाना
# ...

# %%
ep_4_prod[ep_4_prod.Text_id == 47904881]
# Out:
#        Tag   Text_id                        Type_of_text  \
# 10910  287  47904881  multi_speaker_replaced_by_wildcard
# 10911  287  47904881     multi_speaker_replaced_by_blank
#
#                                   Raw_GT                     GT  \
# 10910  कैंडिड बी लिक्विड @ _ @ _ @ _ @ _   कैंडिड बी लिक्विड  _
# 10911  कैंडिड बी लिक्विड @ _ @ _ @ _ @ _  कैंडिड बी लिक्विड   _
#
#               GT(english)                               utf_text  \
# 10910  candid be liquid _  कैंडिड बी लिक्विड शिरोडकर हाई लेटर को
# 10911  candid be liquid _  कैंडिड बी लिक्विड शिरोडकर हाई लेटर को
#
#                      Machine_Transcribed_text  \
# 10910  कैंडिड बी लिक्विड बिन्दिया लेटर कोको
# 10911  कैंडिड बी लिक्विड बिन्दिया लेटर कोको
#
#          Machine_Transcribed_text(English)  GT_len  ...  WER  WER*GT_len  \
# 10910  candid be liquid bindiya later coco       3  ...  0.0         0.0
# 10911  candid be liquid bindiya later coco       3  ...  0.0         0.0
#
# ...

# %%
merged_4th[merged_4th.WER_x > merged_4th.WER_y]
# Out:
#        Tag_x   Text_id                        Type_of_text  \
# 4        287  44554478       primary_speaker_with_wildcard
# 5        287  44554478   primary_speaker_replaced_by_blank
# 8        287  44554626       primary_speaker_with_wildcard
# 9        287  44554626   primary_speaker_replaced_by_blank
# 14       287  44554908  multi_speaker_replaced_by_wildcard
# ...      ...       ...                                 ...
# 13175    287  47906399   primary_speaker_replaced_by_blank
# 13178    287  47906401  multi_speaker_replaced_by_wildcard
# 13179    287  47906401     multi_speaker_replaced_by_blank
# 13200    287  47906414       primary_speaker_with_wildcard
# 13201    287  47906414   primary_speaker_replaced_by_blank
#
#                                                 Raw_GT_x  \
# 4                           चौड़ी लेस वाली साड़ी डिजाइनर
# 5                           चौड़ी लेस वाली साड़ी डिजाइनर
# 8                               टेक्नो कैमन फिफ्टीन प्रो
# ...

# %%
merged_4th[(merged_4th.WER_x > merged_4th.WER_y) & (merged_4th.Type_of_text == 'primary_speaker_with_wildcard')][['Machine_Transcribed_text_x', 'Machine_Transcribed_text_y', 'GT_x', 'WER_x', 'WER_y']]
# Out:
#                                 Machine_Transcribed_text_x  \
# 4                         चौड़े लेस वाली साड़ी डिजाइन है
# 8                              टेक्नो कम ऑन फिफ्टीन प्रो
# 54                                  बारह वोल्ट का स्वेटर
# 92                  मूवी स्टार होम थ्रेड कितना प्रीफिक्स
# 116                            दस साल के लड़के के लिए रे
# ...                                                    ...
# 13062                                     कंट्री रिचार्ज
# 13090                              रिमोट कार डेंजर गाड़ी
# 13124                              सत्ता सिंगी देवी फोटो
# 13174  लड़कों को दौड़ने के लिए कोई हल्का पैंट जो होते है
# 13200                  एक ग्यारह बारह साल की लड़की को तो
#
#                                 Machine_Transcribed_text_y  \
# 4                           चौड़े लेस वाली साड़ी डिजाइनर
# 8                               टेक्नो कॉमन फिफ्टीन प्रो
# 54                                   बारह वोल्ट कैपेसिटर
# ...

# %%
merged_4th[(merged_4th.WER_x < merged_4th.WER_y) & (merged_4th.Type_of_text == 'primary_speaker_with_wildcard')][['Machine_Transcribed_text_x', 'Machine_Transcribed_text_y', 'GT_x', 'WER_x', 'WER_y']]
# Out:
#                      Machine_Transcribed_text_x  \
# 0                     प्लैटिना का शॉकर प्राइस
# 38                  चैन वाली वॉच सौ रुपये में
# 94                            रियलमी नाजो टेन
# 96                डिश एडजेस्ट मशीन यूरी कंपनी
# 154             फ्लफी बनी हेयरबैंड फॉर गर्ल्स
# ...                                         ...
# 12584                   रियलमी थ्री जी रैम का
# 12812  पचास रुपये तक का सफेद पीला राइस दिखाइए
# 13032                          गर्ल मनी वॉलेट
# 13130                      रोज कंपनी के हॉर्न
# 13154          छोटे बच्चों के पैंट और टी शर्ट
#
#                         Machine_Transcribed_text_y  \
# 0                        प्लेटिना का सॉकर प्राइस
# 38                     चेन वाली वॉच सौ रुपये में
# 94                            रियल मी नार जो टेन
# 96                 डिश एयर जेस्ट मशीन यूरी कंपनी
# 154              ट्रॉफी पानी हेयरबैंड फॉर गर्ल्स
# ...                                            ...
# 12584                       रेडमी थ्री जी रैम का
# ...

# %%
merged_4th[(merged_4th.WER_x > merged_4th.WER_y) & (merged_4th.Type_of_text == 'multi_speaker_replaced_by_wildcard')][['Machine_Transcribed_text_x', 'Machine_Transcribed_text_y', 'GT_x', 'WER_x', 'WER_y']]
# Out:
#                                      Machine_Transcribed_text_x  \
# 14                       चार्जिंग बैक टाइटर मोट कंट्रोल कार्स
# 22                                            काटी ओ पी इ सेट
# 24                                                आई बॉल टॉयज
# 72                            सोनी थर्टी टू इंच एल ई डी टी वी
# 74                              स्मॉल कार इन रूपीज ट्वेंटी एट
# ...                                                         ...
# 13076  पार्सले पांच साल लेके राजे बुद्धा लाइट का केलाइट चाहिए
# 13094                 टीवी वीडियो गेम फाइव हंड्रेड रूपीज अंडर
# 13106                                           फोर वाली घड़ी
# 13168                                              रूम संत्री
# 13178                                 हनुमान वाल मारिया कपड़ा
#
#                              Machine_Transcribed_text_y  \
# 14                 चार्जिंग बैटरी रिमोट कंट्रोल कार्स
# 22                                 क्या टी ओ पी ई सेट
# ...

# %%
merged_4th[(merged_4th.WER_x < merged_4th.WER_y) & (merged_4th.Type_of_text == 'multi_speaker_replaced_by_wildcard')][['Machine_Transcribed_text_x', 'Machine_Transcribed_text_y', 'GT_x', 'WER_x', 'WER_y']]
# Out:
#                                                                                Machine_Transcribed_text_x  \
# 18                                                      फ्री चार्जिंग रिमोट कंट्रोल कार इन थाउजेंड बिलो
# 36                                                                                      सैंडल की डिजाइन
# 40                                                                                बजाज नो मार्क्स क्रीम
# 134                                                                        ऑयल स्किन व्हाइटनिंग क्रीम्स
# 138                                                     बच्चों के लिए बहुत सारी घड़ी छोटे बच्चों के लिए
# ...                                                                                                   ...
# 12958                                                    एक साल के बच्चे के लिए जींस पैंट व्हाइट कलर के
# 13014                                                                               ट्रेनीज लेगिंग टॉयज
# ...

# %%
prod_wer_higher = merged_4th[(merged_4th.WER_x < merged_4th.WER_y)]
sns.scatterplot(data=prod_wer_higher , x="tf_predicted_word_len", y="theano_predicted_word_len")
# Out:
# <AxesSubplot:xlabel='tf_predicted_word_len', ylabel='theano_predicted_word_len'>

# %%
prod_wer_lower = merged_4th[(merged_4th.WER_x > merged_4th.WER_y)]
sns.scatterplot(data=prod_wer_lower , x="tf_predicted_word_len", y="theano_predicted_word_len")
# Out:
# <AxesSubplot:xlabel='tf_predicted_word_len', ylabel='theano_predicted_word_len'>
