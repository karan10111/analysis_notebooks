# %%
import pandas as pd

# %%
gp = pd.read_csv("/shared/karan.verma/gp_train_data.txt", sep='|', header=None)
# Out:
# /home/karan.verma/miniconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (1,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
gp[gp[1] == 2720204]
# Out:
#                 0           1             2             3  \
# 1323282  CTCLoss   2.7202e+06    b2sgc28=      b2sgc28=
# 1399290  CTCLoss      2720204    b2sgc28=      b2sgc28=
# 1731725  CTCLoss      2720204    b2sgc28=      b2sgc28=
# 1807733  CTCLoss      2720204    b2sgc28=      b2sgc28=
# 2140168  CTCLoss   2.7202e+06    b2sgc28=      b2sgc28=
# 2216176  CTCLoss   2.7202e+06    b2sgc28=      b2sgc28=
# 2548611  CTCLoss      2720204    b2sgc28=      b2sgc28=
# 2624619  CTCLoss      2720204    b2sgc28=      b2sgc28=
# 2957054  CTCLoss      2720204    b2sgc28=      b2sgc28=
# 3033062  CTCLoss      2720204    b2sgc28=      b2sgc28=
#
#                                                          4  \
# 1323282    /home/software/data/transcription/flacs/my_o...
# 1399290    /home/software/data/transcription/flacs/my_o...
# 1731725    /home/software/data/transcription/flacs/my_o...
# 1807733    /home/software/data/transcription/flacs/my_o...
# ...

# %%
gp.describe()
# Out:
#                0          1             2             3  \
# count    3307402  3307402.0       3307379       3307373
# unique         3  1633388.0        943691        944386
# top     CTCLoss   2720204.0    aGVsbG8=      aGVsbG8=
# freq     3307379       10.0         24696         25339
#
#                                                         4  \
# count                                             3307362
# unique                                            1261557
# top       /home/software/data/transcription/flacs/my_o...
# freq                                                   10
#
#                                           5         6        7        8
# count                               3307351   3307330  3307329  3307327
# unique                               937157    937137      399        3
# top       [0, 52, 0, 62, 0, 47, 0, 66, 0]      हेलो        608
# freq                                  30396     30396   132302  3307325

# %%
gp.drop_duplicates(subset=1)[1].is_unique
# Out:
# True

# %%
gp.drop_duplicates(subset=1)
# Out:
#                                    0                              1  \
# 0                           CTCLoss                     1.28363e+07
# 1                           CTCLoss                     5.45685e+06
# 2                           CTCLoss                     7.09199e+06
# 3                           CTCLoss                     8.26014e+06
# 4                           CTCLoss                     8.22304e+06
# ...                              ...                            ...
# 3134843  time taken end is  CTCLoss                       0.0551622
# 3143131   time taken end is CTCLoss                     3.22457e+07
# 3214683                     CTCLoss                       1808471
# 3272571                     CTCLoss     3052859 time taken end is
# 3278043  time taken end is  CTCLoss                         0.05598
#
#                                                          2  \
# 0                                               d2hhdA==
# ...
